# %% [markdown]
# # Die Binomialverteilung <img src="attachment:hsrmlogo.png" width="10%" align="right">
# Endlich mal wieder ein Python-Notebook! Hier werden wir die Binomialverteilung besser kennenlernen.

# %% [markdown]
# ## 1. Naive Implementierung
#
# $X$ sei eine binomialverteilte Zufallsvariable. Implementieren Sie die Funktion *binomial(n, p)*, die - gegeben eine Anzahl von Versuchen $n$ und eine Erfolgswahrscheinlichkeit $p$ - ein $(n+1)$-dimensionales (Numpy-)Array $P$ mit den Wahrscheinlichkeiten $P(X=0), P(X=1), ..., P(X=n)$ zurückgibt.
#
# Implementieren Sie zunächst die Standard-Formel aus den Slides:
# $$
# P(X=k) = \binom{n}{k} \cdot p^k \cdot (1-p)^{n-k}
# $$
# Nutzen Sie <a href="https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.special.binom.html">scipy.special.binom()</a> zur Berechnung des Binomialkoeffizienten.
# Berechnen Sie $P$ und plotten Sie es mit der unten definierten Methode *barplot()*. Variieren Sie $n=3,10,100$ und $p=0.1, 0.5, 0.99$. Sehen die Werte vernünftig aus?

# %%
# %matplotlib inline 

from scipy.special import binom
import numpy as np
import matplotlib.pyplot as plt

def binomial(n, p):
    # FIXME: compute array P
    P = []
    for k in range(n+1):
        #print(k)
        binomial = binom(n, k) * pow(p, k) * pow(1-p, n-k)
        print(binomial)
        P.append(binomial)
    return np.array(P)


def barplot(P):
    ind = np.arange(0,len(P))
    fig, ax = plt.subplots()
    rects1 = ax.bar(ind+0.5, P, 0.8, color='red')
    ax.set_ylabel('P(X=k)')
    ax.set_xlabel('k')
    plt.grid(True)
    plt.show()


P = binomial(10, 0.3)
barplot(P)
# Out:
# 0.02824752489999998
# 0.12106082099999993
# 0.23347444049999988
# 0.2668279319999998
# 0.2001209489999999
# 0.10291934519999994
# 0.03675690899999999
# 0.009001691999999995
# 0.0014467004999999993
# 0.00013778099999999996
# 5.9048999999999975e-06

# %% [markdown]
# # 2. Anwendung: Bauteile prüfen
#
# In einer Fabrik werden mit einer Ausschussrate von 1.5% Bauteile produziert. Es werden per automatischer Kamera-Überwachung 10,000 Bauteile geprüft. $X$ sei die Anzahl der defekten Bauteile. Wir berechnen in der folgenden Zelle mit Hilfe der obigen Methode **binomial()** die Wahrscheinlichkeit, dass mehr als 150 Bauteile defekt sind *(siehe unten)*.
#
# Wir erhalten als Ergebnis "nan" *(not a number)*. ***Erläutern Sie warum***.

# %%
P = binomial(10000, 0.015)
print(sum(P[151:]))
# Out:
# 2.3030585344519585e-66
# 3.5071957377440994e-64
# 2.6701865620586233e-62
# 1.3551535658610207e-60
# 5.157666319002268e-59
# 1.5702344931394928e-57
# 3.9833740504896517e-56
# 8.660588889179167e-55
# 1.6474352430755223e-53
# 2.7853084515754e-52
# 4.237769046653272e-51
# 5.860910859630761e-50
# 7.429522662037012e-49
# 8.692628545305626e-48
# 9.44306902994568e-47
# 9.573450490663713e-46
# 9.098118954563181e-45
# 8.136962046195175e-44
# 6.87235973833895e-43
# 5.498255001984992e-42
# 4.178534251977194e-41
# 3.02405887124911e-40
# 2.08886133891367e-39
# 1.3800038693235944e-38
# 8.736230078755403e-38
# 5.308789721761237e-37
# 3.101630855612942e-36
# 1.7448204260538257e-35
# 9.463974315786182e-35
# 4.955789526290615e-34
# 2.5083338764733953e-33
# 1.2284962542289111e-32
# 5.828146807607176e-32
# 2.6808937414756718e-31
# 1.19679611472685e-30
# 5.1895301287543045e-30
# 2.1875493965116678e-29
# 8.971083353197827e-29
# 3.5818422433909575e-28
# 1.3932960729495583e-27
# 5.283739409784641e-27
# ...

# %% [markdown]
# Zahlen mit denen gerechnt wird sind zu groß/klein
#
# 10000 über 150 wird zu groß
#
# 0.015^210 sind so klein, dass es auf dem TR schon 0 ergibt

# %% [markdown]
# ## 3. Rekursionsformel
#
# Implementieren Sie nun eine zweite Methode *binomial_recursive()*, die die Rekursionsformel für die Binomialverteilung verwendet *(siehe Beweis auf dem Übungsblatt)*.
#
# * Hinweis: Denken Sie daran, P[0] mit $P(X=0)$ zu initialisieren.
# * Überprüfen Sie per Barplot, dass Ihr Ergebnis immer noch korrekt ist.
# * Testen Sie das Fabrikbeispiel aus Teil 2. Erhalten Sie nun ein plausibles Ergebnis?

# %%
import numpy as np

def binomial_recursive(n, p):
    # FIXME: fill P
    # P(X = 0)
    P_list = []
    P = binom(n, 0) * pow(p, 0) * pow(1-p, n-0)
    P_list.append(P)
    for k in range(n+1):
        P *= (p / (1-p)) * ((n-k) / (k+1))
        P_list.append(P)
    return np.array(P_list)


P = binomial_recursive(10, 0.5)
barplot(P)


P = binomial_recursive(10000, 0.015)
print(sum(P[151:]))
# Out:
# 0.4783022005917221

# %% [markdown]
# ja ich erhlate ein Ergebnis es erscheint mir jedoch etwas hoch
